# %% [raw]
# #

# %%
ENV_NAME = 'eda'
ENV_DIR = r'D:\Virtual_Env'

change_dir = 'cd ' + ENV_DIR

#create the virtual environment
create = 'python -m venv --system-site-packages ' + ENV_NAME

#activate the virtual environment
activate = '.\\' + ENV_NAME + r'\Scripts\activate'

#install to properly sync with Jupyter
upgrade = 'python -m pip install --upgrade pip'
upgrade2 = 'pip install --upgrade pywin32==225'

#sync with jupyter
install = 'pip install ipykernel'
install2 = 'python -m ipykernel install --user --name=' + ENV_NAME


# !{change_dir} && {create} && {activate} && {upgrade} && {upgrade2} && {install} &&{install2}
# Out:
# Collecting pip
#   Using cached pip-21.1.2-py3-none-any.whl (1.5 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.3
#     Uninstalling pip-20.2.3:
#       Successfully uninstalled pip-20.2.3
# Successfully installed pip-21.1.2
# Collecting pywin32==225
#   Using cached pywin32-225-cp38-cp38-win_amd64.whl (9.1 MB)
# Installing collected packages: pywin32
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 227
#     Not uninstalling pywin32 at c:\users\blain\anaconda3\lib\site-packages, outside environment d:\virtual_env\eda
#     Can't uninstall 'pywin32'. No files were found to uninstall.
# Successfully installed pywin32-225
# Requirement already satisfied: ipykernel in c:\users\blain\anaconda3\lib\site-packages (5.3.4)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\blain\anaconda3\lib\site-packages (from ipykernel) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in c:\users\blain\anaconda3\lib\site-packages (from ipykernel) (6.1)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\blain\anaconda3\lib\site-packages (from ipykernel) (7.22.0)
# Requirement already satisfied: jupyter-client in c:\users\blain\anaconda3\lib\site-packages (from ipykernel) (6.1.12)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in d:\virtual_env\eda\lib\site-packages (from ipython>=5.0.0->ipykernel) (49.2.1)
# Requirement already satisfied: backcall in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.2.0)
# Requirement already satisfied: colorama in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.4.4)
# Requirement already satisfied: decorator in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (5.0.6)
# Requirement already satisfied: pickleshare in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (0.7.5)
# Requirement already satisfied: pygments in c:\users\blain\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel) (2.8.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\blain\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\blain\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\blain\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\blain\anaconda3\lib\site-packages (from jupyter-client->ipykernel) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\blain\anaconda3\lib\site-packages (from jupyter-client->ipykernel) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\blain\anaconda3\lib\site-packages (from jupyter-client->ipykernel) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in d:\virtual_env\eda\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel) (225)
# Requirement already satisfied: six>=1.5 in c:\users\blain\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel) (1.15.0)
# Installed kernelspec eda in C:\Users\blain\AppData\Roaming\jupyter\kernels\eda

# %% [markdown]
# # CHANGE THE KERNEL

# %% [markdown]
# # Install the necessary packages

# %%
import sys
# !{sys.executable} -m pip list
# Out:
# Package                            Version
# ---------------------------------- -----------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.9
# conda                              4.10.1
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# gevent                             21.1.2
# glob2                              0.7
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.1.2
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            225
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         49.2.1
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
#this is the base environment
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.9
# conda                              4.10.1
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# gevent                             21.1.2
# glob2                              0.7
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.0.1
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            225
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
import sys

# %pip install wheel
# %pip install pipwin
# %pip install numpy
# !{sys.executable} -m pipwin install pandas
# !{sys.executable} -m pipwin install shapely
# !{sys.executable} -m pipwin install gdal
# !{sys.executable} -m pipwin install fiona
# !{sys.executable} -m pipwin install pyproj
# !{sys.executable} -m pipwin install six
# !{sys.executable} -m pipwin install rtree
# !{sys.executable} -m pipwin install geopandas
# %pip install opencv-python
# %pip install pygeos
#%pip install matplotlib
# Out:
# Requirement already satisfied: wheel in c:\users\blain\anaconda3\lib\site-packages (0.36.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting pipwin
#   Using cached pipwin-0.5.1-py2.py3-none-any.whl
# Requirement already satisfied: requests in c:\users\blain\anaconda3\lib\site-packages (from pipwin) (2.25.1)
# Requirement already satisfied: packaging in c:\users\blain\anaconda3\lib\site-packages (from pipwin) (20.9)
# Requirement already satisfied: six in c:\users\blain\anaconda3\lib\site-packages (from pipwin) (1.15.0)
# Collecting pySmartDL>=1.3.1
#   Using cached pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\users\blain\anaconda3\lib\site-packages (from pipwin) (4.9.3)
# Collecting pyprind
#   Using cached PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Collecting docopt
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting js2py
#   Using cached Js2Py-0.71-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\blain\anaconda3\lib\site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.2.1)
# Collecting pyjsparser>=2.5.1
#   Using cached pyjsparser-2.7.1-py3-none-any.whl
# Collecting tzlocal>=1.2
#   Using cached tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pytz in c:\users\blain\anaconda3\lib\site-packages (from tzlocal>=1.2->js2py->pipwin) (2021.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\blain\anaconda3\lib\site-packages (from packaging->pipwin) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\blain\anaconda3\lib\site-packages (from requests->pipwin) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\blain\anaconda3\lib\site-packages (from requests->pipwin) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\blain\anaconda3\lib\site-packages (from requests->pipwin) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\blain\anaconda3\lib\site-packages (from requests->pipwin) (2020.12.5)
# Installing collected packages: tzlocal, pyjsparser, pySmartDL, pyprind, js2py, docopt, pipwin
# Successfully installed docopt-0.6.2 js2py-0.71 pipwin-0.5.1 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 tzlocal-2.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\blain\anaconda3\lib\site-packages (1.20.1)
# Note: you may need to restart the kernel to use updated packages.
# Package `pandas` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/pandas-1.2.4-cp38-cp38-win_amd64.whl
# pandas-1.2.4-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 8.7 MB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 8.7 MB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 8.7 MB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 8.7 MB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 40 kB / 8.7 MB @ 80 kB/s [------------------] [0.4%, 0s left]   [*] 88 kB / 8.7 MB @ 147 kB/s [------------------] [1.0%, 0s left]  [*] 216 kB / 8.7 MB @ 309 kB/s [------------------] [2.4%, 0s left]   [*] 424 kB / 8.7 MB @ 530 kB/s [------------------] [4.8%, 0s left]   [*] 552 kB / 8.7 MB @ 613 kB/s [#-----------------] [6.2%, 0s left]   [*] 904 kB / 8.7 MB @ 904 kB/s [#-----------------] [10.1%, 0s left]  [*] 1.3 MB / 8.7 MB @ 1.2 MB/s [##----------------] [15.0%, 0s left]  [*] 2.0 MB / 8.7 MB @ 1.7 MB/s [####--------------] [22.9%, 0s left]  [*] 3.1 MB / 8.7 MB @ 2.4 MB/s [######------------] [35.2%, 0s left]  [*] 4.4 MB / 8.7 MB @ 3.1 MB/s [#########---------] [50.3%, 0s left]  [*] 5.9 MB / 8.7 MB @ 4.0 MB/s [############------] [68.1%, 0s left]  [*] 8.3 MB / 8.7 MB @ 5.2 MB/s [#################-] [94.8%, 0s left]  Processing c:\users\blain\pipwin\pandas-1.2.4-cp38-cp38-win_amd64.whl
# Requirement already satisfied: pytz>=2017.3 in c:\users\blain\anaconda3\lib\site-packages (from pandas==1.2.4) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\blain\anaconda3\lib\site-packages (from pandas==1.2.4) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\blain\anaconda3\lib\site-packages (from pandas==1.2.4) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\blain\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.2.4) (1.15.0)
# pandas is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# [*] 8.7 MB / 8.7 MB @ 5.2 MB/s [##################] [100%, 0s left]
# Package `shapely` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/Shapely-1.7.1-cp38-cp38-win_amd64.whl
# Shapely-1.7.1-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 590 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 590 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 590 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 590 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 40 kB / 590 kB @ 80 kB/s [#-----------------] [6.8%, 0s left]   [*] 88 kB / 590 kB @ 147 kB/s [##----------------] [14.9%, 0s left]   [*] 248 kB / 590 kB @ 354 kB/s [#######-----------] [42.1%, 0s left]  [*] 472 kB / 590 kB @ 590 kB/s [##############----] [80.0%, 0s left]  Processing c:\users\blain\pipwin\shapely-1.7.1-cp38-cp38-win_amd64.whl
# Installing collected packages: Shapely
# Successfully installed Shapely-1.7.1
# [*] 590 kB / 590 kB @ 590 kB/s [##################] [100%, 0s left]
# Package `gdal` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/GDAL-3.3.0-cp38-cp38-win_amd64.whl
# GDAL-3.3.0-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 22.1 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 22.1 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 22.1 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 22.1 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 40 kB / 22.1 MB @ 80 kB/s [------------------] [0.2%, 0s left]  [*] 72 kB / 22.1 MB @ 120 kB/s [------------------] [0.3%, 0s left]   [*] 168 kB / 22.1 MB @ 240 kB/s [------------------] [0.7%, 0s left]  [*] 344 kB / 22.1 MB @ 430 kB/s [------------------] [1.5%, 0s left]  [*] 520 kB / 22.1 MB @ 578 kB/s [------------------] [2.3%, 0s left]  [*] 792 kB / 22.1 MB @ 792 kB/s [------------------] [3.5%, 0s left]  [*] 1.1 MB / 22.1 MB @ 1.0 MB/s [------------------] [5.1%, 0s left]  [*] 1.8 MB / 22.1 MB @ 1.5 MB/s [#-----------------] [8.3%, 0s left]  [*] 2.8 MB / 22.1 MB @ 2.1 MB/s [##----------------] [12.5%, 0s left]   [*] 4.3 MB / 22.1 MB @ 3.0 MB/s [###---------------] [19.3%, 0s left]   [*] 5.7 MB / 22.1 MB @ 3.8 MB/s [####--------------] [26.0%, 0s left]   [*] 8.3 MB / 22.1 MB @ 5.2 MB/s [######------------] [37.7%, 0s left]   [*] 11.6 MB / 22.1 MB @ 6.8 MB/s [#########---------] [52.5%, 0s left]  [*] 15.5 MB / 22.1 MB @ 8.6 MB/s [############------] [70.1%, 0s left]  [*] 19.8 MB / 22.1 MB @ 10.4 MB/s [################--] [89.8%, 0s left]   Processing c:\users\blain\pipwin\gdal-3.3.0-cp38-cp38-win_amd64.whl
# Installing collected packages: GDAL
# Successfully installed GDAL-3.3.0
# [*] 22.1 MB / 22.1 MB @ 10.4 MB/s [##################] [100%, 0s left]
# Package `fiona` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/Fiona-1.8.20-cp38-cp38-win_amd64.whl
# Fiona-1.8.20-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 535 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 535 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 535 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 535 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 40 kB / 535 kB @ 80 kB/s [#-----------------] [7.5%, 0s left]   [*] 136 kB / 535 kB @ 227 kB/s [####--------------] [25.4%, 0s left]  [*] 232 kB / 535 kB @ 331 kB/s [#######-----------] [43.4%, 0s left]  [*] 488 kB / 535 kB @ 610 kB/s [################--] [91.3%, 0s left]  Processing c:\users\blain\pipwin\fiona-1.8.20-cp38-cp38-win_amd64.whl
# Requirement already satisfied: gdal~=3.3.0 in d:\virtual_env\eda\lib\site-packages (from Fiona==1.8.20) (3.3.0)
# Collecting munch
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: setuptools in d:\virtual_env\eda\lib\site-packages (from Fiona==1.8.20) (49.2.1)
# Requirement already satisfied: six>=1.7 in c:\users\blain\anaconda3\lib\site-packages (from Fiona==1.8.20) (1.15.0)
# Requirement already satisfied: click>=4.0 in c:\users\blain\anaconda3\lib\site-packages (from Fiona==1.8.20) (7.1.2)
# Collecting cligj>=0.5
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: attrs>=17 in c:\users\blain\anaconda3\lib\site-packages (from Fiona==1.8.20) (20.3.0)
# Collecting click-plugins>=1.0
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: certifi in c:\users\blain\anaconda3\lib\site-packages (from Fiona==1.8.20) (2020.12.5)
# Installing collected packages: munch, cligj, click-plugins, Fiona
# Successfully installed Fiona-1.8.20 click-plugins-1.1.1 cligj-0.7.2 munch-2.5.0
# [*] 535 kB / 535 kB @ 610 kB/s [##################] [100%, 0s left]
# Package `pyproj` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/pyproj-3.1.0-cp38-cp38-win_amd64.whl
# pyproj-3.1.0-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 13.9 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 13.9 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 13.9 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 13.9 MB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 8 kB / 13.9 MB @ 16 kB/s [------------------] [0.1%, 0s left]   [*] 72 kB / 13.9 MB @ 120 kB/s [------------------] [0.5%, 0s left]   [*] 168 kB / 13.9 MB @ 240 kB/s [------------------] [1.2%, 0s left]  [*] 264 kB / 13.9 MB @ 330 kB/s [------------------] [1.9%, 0s left]  [*] 504 kB / 13.9 MB @ 560 kB/s [------------------] [3.6%, 0s left]  [*] 680 kB / 13.9 MB @ 680 kB/s [------------------] [4.8%, 0s left]  [*] 1.1 MB / 13.9 MB @ 1.0 MB/s [#-----------------] [8.3%, 0s left]  [*] 1.6 MB / 13.9 MB @ 1.3 MB/s [##----------------] [11.7%, 0s left]   [*] 2.3 MB / 13.9 MB @ 1.8 MB/s [###---------------] [16.9%, 0s left]   [*] 3.6 MB / 13.9 MB @ 2.6 MB/s [####--------------] [25.9%, 0s left]   [*] 4.9 MB / 13.9 MB @ 3.2 MB/s [######------------] [35.0%, 0s left]   [*] 6.7 MB / 13.9 MB @ 4.2 MB/s [########----------] [48.2%, 0s left]   [*] 9.4 MB / 13.9 MB @ 5.5 MB/s [############------] [67.6%, 0s left]   [*] 12.6 MB / 13.9 MB @ 7.0 MB/s [################--] [91.3%, 0s left]  Processing c:\users\blain\pipwin\pyproj-3.1.0-cp38-cp38-win_amd64.whl
# Requirement already satisfied: certifi in c:\users\blain\anaconda3\lib\site-packages (from pyproj==3.1.0) (2020.12.5)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.1.0
# [*] 13.9 MB / 13.9 MB @ 7.0 MB/s [##################] [100%, 0s left]
# Package `six` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/six-1.16.0-py3-none-any.whl
# six-1.16.0-py3-none-any.whl
# [*] 0 bytes / 11 kB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 11 kB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 11 kB @ 0 bytes/s [------------------] [0.0%, 0s left]  [*] 0 bytes / 11 kB @ 0 bytes/s [------------------] [0.0%, 0s left]  Processing c:\users\blain\pipwin\six-1.16.0-py3-none-any.whl
# Installing collected packages: six
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Not uninstalling six at c:\users\blain\anaconda3\lib\site-packages, outside environment D:\Virtual_Env\eda
#     Can't uninstall 'six'. No files were found to uninstall.
# Successfully installed six-1.16.0
# [*] 11 kB / 11 kB @ 0 bytes/s [##################] [100%, 0s left]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# Package `rtree` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/Rtree-0.9.7-cp38-cp38-win_amd64.whl
# Rtree-0.9.7-cp38-cp38-win_amd64.whl
# [*] 0 bytes / 322 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 322 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 322 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 322 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 8 kB / 322 kB @ 16 kB/s [------------------] [2.5%, 0s left]  [*] 88 kB / 322 kB @ 147 kB/s [####--------------] [27.3%, 0s left]   [*] 248 kB / 322 kB @ 354 kB/s [#############-----] [77.0%, 0s left]  Processing c:\users\blain\pipwin\rtree-0.9.7-cp38-cp38-win_amd64.whl
# Rtree is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# [*] 322 kB / 322 kB @ 354 kB/s [##################] [100%, 0s left]
# Package `geopandas` found in cache
# Downloading package . . .
# https://download.lfd.uci.edu/pythonlibs/q4trcu4l/geopandas-0.9.0-py3-none-any.whl
# geopandas-0.9.0-py3-none-any.whl
# [*] 0 bytes / 971 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 971 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 971 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 0 bytes / 971 kB @ 0 bytes/s [------------------] [0.0%, 0s left]   [*] 40 kB / 971 kB @ 80 kB/s [------------------] [4.1%, 0s left]   [*] 72 kB / 971 kB @ 120 kB/s [#-----------------] [7.4%, 0s left]  [*] 184 kB / 971 kB @ 263 kB/s [###---------------] [18.9%, 0s left]  [*] 408 kB / 971 kB @ 510 kB/s [#######-----------] [42.0%, 0s left]  [*] 552 kB / 971 kB @ 613 kB/s [##########--------] [56.8%, 0s left]  [*] 904 kB / 971 kB @ 904 kB/s [################--] [93.1%, 0s left]  Processing c:\users\blain\pipwin\geopandas-0.9.0-py3-none-any.whl
# Requirement already satisfied: pandas>=0.24.0 in c:\users\blain\anaconda3\lib\site-packages (from geopandas==0.9.0) (1.2.4)
# Requirement already satisfied: pyproj>=2.2.0 in d:\virtual_env\eda\lib\site-packages (from geopandas==0.9.0) (3.1.0)
# Requirement already satisfied: shapely>=1.6 in d:\virtual_env\eda\lib\site-packages (from geopandas==0.9.0) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in d:\virtual_env\eda\lib\site-packages (from geopandas==0.9.0) (1.8.20)
# Requirement already satisfied: munch in d:\virtual_env\eda\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (2.5.0)
# Requirement already satisfied: certifi in c:\users\blain\anaconda3\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (2020.12.5)
# Requirement already satisfied: cligj>=0.5 in d:\virtual_env\eda\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (0.7.2)
# Requirement already satisfied: setuptools in d:\virtual_env\eda\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (49.2.1)
# Requirement already satisfied: click-plugins>=1.0 in d:\virtual_env\eda\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (1.1.1)
# Requirement already satisfied: attrs>=17 in c:\users\blain\anaconda3\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (20.3.0)
# Requirement already satisfied: click>=4.0 in c:\users\blain\anaconda3\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (7.1.2)
# Requirement already satisfied: gdal~=3.3.0 in d:\virtual_env\eda\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (3.3.0)
# Requirement already satisfied: six>=1.7 in d:\virtual_env\eda\lib\site-packages (from fiona>=1.8->geopandas==0.9.0) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\blain\anaconda3\lib\site-packages (from pandas>=0.24.0->geopandas==0.9.0) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\blain\anaconda3\lib\site-packages (from pandas>=0.24.0->geopandas==0.9.0) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\blain\anaconda3\lib\site-packages (from pandas>=0.24.0->geopandas==0.9.0) (1.20.1)
# Installing collected packages: geopandas
# Successfully installed geopandas-0.9.0
# [*] 971 kB / 971 kB @ 904 kB/s [##################] [100%, 0s left]
# Collecting opencv-python
#   Using cached opencv_python-4.5.2.54-cp38-cp38-win_amd64.whl (34.7 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\blain\anaconda3\lib\site-packages (from opencv-python) (1.20.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.2.54
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import the necessary packages

# %%
# Out:
# Collecting pygeosNote: you may need to restart the kernel to use updated packages.
#   Using cached pygeos-0.10-cp38-cp38-win_amd64.whl (1.1 MB)
# Requirement already satisfied: numpy>=1.13 in c:\users\blain\anaconda3\lib\site-packages (from pygeos) (1.20.1)
# Installing collected packages: pygeos
# Successfully installed pygeos-0.10

# %%
#to import the geojson as a pandas like dataframe
import geopandas as gpd
import os
import cv2
import random
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Exploratory Data Analysis

# %%
LOCAL_GIT_PATH = R'D:\Github'
DATA_DIR_PATH = r'D:\Data'

XVIEW_UTILS_PATH = LOCAL_GIT_PATH
TF_INSTALL_PATH = LOCAL_GIT_PATH + r'\models'
GEOJSON_FILE = 'xView_train'
CLASS_LABELS_FILE = 'xview_class_labels.txt'

# %%
#Filenames and locations
paths = {
    'WORK_PATH': os.path.join(TF_INSTALL_PATH, 'workspace'),
    'DATA_PATH': DATA_DIR_PATH,
    'IMAGE_PATH': os.path.join(DATA_DIR_PATH, 'train_images', '')
}

files = {
    'GEOJSON_IN': os.path.join(paths['DATA_PATH'], GEOJSON_FILE + '.geojson'),
    'GEOJSON_OUT': os.path.join(paths['DATA_PATH'], GEOJSON_FILE + '_' + 'clean' + '.geojson'),
    'CLASS_LABELS': os.path.join(paths['DATA_PATH'], CLASS_LABELS_FILE)
}

# %%
#read in the geojson
regions = gpd.read_file(files['GEOJSON_IN'])

# %%
used_ids = regions.type_id.unique()

# %%
os.chdir(paths['DATA_PATH'])
#read in the class labels
class_dict = {}
file = open(files['CLASS_LABELS'], "r")

#create a class label dictionary
for line in file:
    key, value = line.split(':')
    class_dict[int(key)] = value.strip()
    
given_ids = [key for key, vals in class_dict.items()]

# %%
extra_classes = [item for item in used_ids if item not in given_ids]

print(extra_classes)
# Out:
# [75, 82]

# %%
#split the bounds box
names = ["x1", "y1", "x2", "y2"]
regions[names] = regions['bounds_imcoords'].str.split(',', expand=True)
regions[names] = regions[names].astype(int)
regions['bottom'] = regions.y2 - regions.y1
regions['top'] = regions.x2 - regions.x1
regions['area'] = regions.bottom * regions.top

# %%
#delete any rows which contain a bounding box with a small x or y dimension
prior = len(regions)

regions = regions[regions.top > 10]
regions = regions[regions.bottom > 10]

post = len(regions)
print('Removed {} small regions.'.format(prior-post))



#remove invalid ids
prior = len(regions)

regions = regions[~regions.type_id.isin(extra_classes)]
post = len(regions)

print('Removed {} invalid id types.'.format(prior-post))

#remove regions with negative locations
prior = len(regions)

regions = regions[~regions.x1 < 0]
regions = regions[~regions.y1 < 0]
post = len(regions)

print('Removed {} invalid region locations.'.format(prior-post))
# Out:
# Removed 133384 small regions.
# Removed 79 invalid id types.
# Removed 4837 invalid region locations.

# %%
regions['ratio'] = regions.top / regions.bottom
regions.hist(column='ratio', bins=25,range=(0, 3))
# Out:
# array([[<AxesSubplot:title={'center':'ratio'}>]], dtype=object)

# %%
#the area of the bounding box in pixels
regions.hist(column='area', bins=50, range=(0,1000))
# Out:
# array([[<AxesSubplot:title={'center':'area'}>]], dtype=object)

# %%
#the x size of the bounding box in pixels
regions.hist(column='top', bins=25, range=(0,200))
# Out:
# array([[<AxesSubplot:title={'center':'top'}>]], dtype=object)

# %%
#the y size of the bounding box in pixels
regions.hist(column='bottom', bins=25, range=(0,150))
# Out:
# array([[<AxesSubplot:title={'center':'bottom'}>]], dtype=object)

# %%
regions.type_id.value_counts()
# Out:
# 73    309942
# 18     92347
# 23      9797
# 19      5551
# 24      4593
# 83      4133
# 25      3432
# 27      3111
# 21      2451
# 89      2270
# 35      1790
# 86      1594
# 34      1585
# 91      1313
# 17      1231
# 60      1210
# 41      1177
# 79      1169
# 72      1156
# 76      1067
# 77       897
# 28       821
# 64       818
# 26       753
# 13       677
# 47       655
# 71       614
# 63       602
# 42       598
# 40       596
# 20       586
# 50       443
# 93       366
# 12       361
# 61       331
# 59       325
# 51       305
# 65       268
# 44       219
# 53       198
# 74       198
# 49       192
# 45       186
# 55       174
# 32       169
# 54       153
# 29       141
# 84       121
# 38       120
# 37       118
# 36       117
# 94        83
# 66        80
# 52        76
# 11        73
# 15        70
# 62        68
# 56        68
# 57        62
# 33        16
# Name: type_id, dtype: int64

# %%
regions.hist(column='type_id', bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'type_id'}>]], dtype=object)

# %%
#save a new geoJSON file to be used later
regions.drop(columns=names)
regions.drop(columns=['bottom', 'top', 'ratio', 'area'])
regions.to_file(files['GEOJSON_OUT'], driver='GeoJSON')

# %% [markdown]
# # View images and overlay bounding boxes

# %%
image_name = '10.tif'

test_image = os.path.join(paths['IMAGE_PATH'], image_name)
test_regions = regions[regions['image_id'] == image_name]

# %%
window_name = 'Image'
image = cv2.imread(test_image)
#create a color dictionary for the different ID types
color_dict = {}
type_set = test_regions.type_id.unique()

# font needed for text
font = cv2.FONT_HERSHEY_SIMPLEX

for type_id in type_set:
    color_dict[type_id] = (random.randint(0,255), random.randint(0,255), random.randint(0,255))


#loop through the region and find all of the objects, then place them on the image
for i in range(len(test_regions)):
    lst_int = [int(x) for x in test_regions.iloc[i]['bounds_imcoords'].split(",")]
    id_type = test_regions.type_id.iloc[i]
    topleft = (lst_int[0], lst_int[1])
    
    bottomright = (lst_int[2], lst_int[3])
    image = cv2.rectangle(image, topleft, bottomright, color=color_dict[id_type], thickness=1)
    #image = cv2.putText(image, ('ID: ' + str(id_type)), topleft)
    image = cv2.putText(image, class_dict[id_type], topleft, font, 
                   fontScale=0.5, color=color_dict[id_type], thickness=2)
    
# Display the image 
cv2.imshow(window_name, image) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
regions2 = gpd.read_file(files['GEOJSON_OUT'])

# %%
regions2
# Out:
#             bounds_imcoords        edited_by            cat_id  type_id  \
# 0       2712,1145,2746,1177  wwoscarbecerril  1040010028371A00       73
# 1       2720,2233,2760,2288  wwoscarbecerril  1040010028371A00       73
# 2       2687,1338,2740,1399  wwoscarbecerril  1040010028371A00       73
# 3       2691,1201,2730,1268  wwoscarbecerril  1040010028371A00       73
# 4         2671,838,2714,869  wwoscarbecerril  1040010028371A00       73
# ...                     ...              ...               ...      ...
# 463632    710,1900,738,1925  wwoscarbecerril  1040010029A6F400       73
# 463633    2091,258,2138,295  wwoscarbecerril  1040010029A6F400       73
# 463634    2106,361,2124,379  wwoscarbecerril  1040010029A6F400       73
# 463635      1917,38,1958,64  wwoscarbecerril  1040010029A6F400       73
# 463636      2323,55,2349,74  wwoscarbecerril  1040010029A6F400       73
#
#                              ingest_time  index_right  image_id  \
# 0       2017-07-24T12:49:09.118000+00:00         2356  2355.tif
# 1       2017-07-24T17:26:05.701000+00:00         2356  2355.tif
# 2       2017-07-24T12:45:09.081000+00:00         2356  2355.tif
# 3       2017-07-24T12:49:09.118000+00:00         2356  2355.tif
# 4       2017-07-24T13:20:38.279999+00:00         2356  2355.tif
# ...                                  ...          ...       ...
# 463632  2017-07-20T19:53:58.250999+00:00          389   389.tif
# 463633  2017-07-20T19:58:09.621000+00:00          389   389.tif
# 463634  2017-07-20T19:58:09.621000+00:00          389   389.tif
# 463635  2017-07-20T20:00:09.628000+00:00          389   389.tif
# 463636  2017-07-20T20:01:06.747000+00:00          389   389.tif
#
#                                                point_geom  feature_id  \
# 0       0101000020E6100000616E4E6406A256C03BE6ADA0D621...      374410
# 1       0101000020E6100000042D0CC705A256C0004F7071E71F...      394393
# 2       0101000020E6100000B29F7E4707A256C0000AE6537921...      374031
# 3       0101000020E6100000CE53137207A256C00EBF7084B521...      374409
# 4       0101000020E610000060DE147608A256C05D6A384C6122...      377368
# ...                                                   ...         ...
# 463632  0101000020E6100000CF0EE83357B958406B326375013F...      319871
# 463633  0101000020E610000000632E73A6B95840B722198AA84A...      320284
# 463634  0101000020E610000056BA697BA6B958407F027597FE49...      320300
# 463635  0101000020E61000003C99A0629CB95840CE2F5BD4444C...      320500
# 463636  0101000020E610000066CC2912B3B95840C97ECDAB2B4C...      320643
#
#          grid_file    x1    y1    x2    y2  bottom  top  area     ratio  \
# 0        Grid2.shp  2712  1145  2746  1177      32   34  1088  1.062500
# 1        Grid2.shp  2720  2233  2760  2288      55   40  2200  0.727273
# 2        Grid2.shp  2687  1338  2740  1399      61   53  3233  0.868852
# 3        Grid2.shp  2691  1201  2730  1268      67   39  2613  0.582090
# 4        Grid2.shp  2671   838  2714   869      31   43  1333  1.387097
# ...            ...   ...   ...   ...   ...     ...  ...   ...       ...
# 463632  Grid97.shp   710  1900   738  1925      25   28   700  1.120000
# 463633  Grid97.shp  2091   258  2138   295      37   47  1739  1.270270
# 463634  Grid97.shp  2106   361  2124   379      18   18   324  1.000000
# 463635  Grid97.shp  1917    38  1958    64      26   41  1066  1.576923
# 463636  Grid97.shp  2323    55  2349    74      19   26   494  1.368421
#
#                                                  geometry
# 0       POLYGON ((-90.53170 14.56604, -90.53170 14.566...
# 1       POLYGON ((-90.53167 14.56222, -90.53167 14.562...
# 2       POLYGON ((-90.53179 14.56527, -90.53179 14.565...
# 3       POLYGON ((-90.53177 14.56572, -90.53177 14.565...
# 4       POLYGON ((-90.53184 14.56710, -90.53184 14.567...
# ...                                                   ...
# 463632  POLYGON ((98.89590 3.65572, 98.89590 3.65581, ...
# 463633  POLYGON ((98.90070 3.66139, 98.90070 3.66152, ...
# 463634  POLYGON ((98.90075 3.66110, 98.90075 3.66116, ...
# 463635  POLYGON ((98.90010 3.66220, 98.90010 3.66229, ...
# 463636  POLYGON ((98.90151 3.66216, 98.90151 3.66223, ...
#
# [463637 rows x 19 columns]
